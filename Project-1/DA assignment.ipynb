# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\ADMIN\Downloads\Weather_Data.csv")

# %%
d = data.copy()

# %%
d.shape
# Out:
# (8784, 8)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
d.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.3              -3.5         18                9
# 1  1/1/2012 1:00     7.4               2.8         20               24
# 2  1/1/2012 2:00    15.7              13.4         21               26
# 3  1/1/2012 3:00     4.9              -2.6         27               15
# 4  1/1/2012 4:00   -13.4             -19.7         30                4
#
#    Visibility_km  Press_kPa        Weather
# 0           25.0      98.67          Clear
# 1           24.1      99.37           Rain
# 2           25.0      99.84         Cloudy
# 3           24.1     100.94   Mainly Clear
# 4           25.0     102.32  Mostly Cloudy

# %% [markdown]
# # Find all the unique 'Wind Speed' values in the data.

# %%
d['Wind Speed_km/h'].unique()
# Out:
# array([ 9, 24, 26, 15,  4,  0, 19, 17, 11, 22, 35, 13, 20,  6,  7, 30, 32,
#        41, 39, 28, 44, 33, 37, 52, 46,  2, 50, 48, 57, 63, 43, 83, 70, 54],
#       dtype=int64)

# %% [markdown]
# # 2) Find the number of times when the 'Weather is exactly Clear'.

# %%
a=d.loc[(d['Weather']=="Clear")]

# %%
len(a)
# Out:
# 1326

# %% [markdown]
# # 3) Find the number of times when the 'Wind Speed was exactly 4 km/h'.

# %%
b=d.loc[(d['Wind Speed_km/h']==4)]

# %%
len(b)
# Out:
# 474

# %% [markdown]
# # 4) Find out all the Null Values in the data

# %%
c=d.isnull().any()

# %%
c
# Out:
# Date/Time           False
# Temp_C              False
# Dew Point Temp_C    False
# Rel Hum_%           False
# Wind Speed_km/h     False
# Visibility_km       False
# Press_kPa           False
# Weather             False
# dtype: bool

# %%
d.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# # 5) Rename the column name 'Weather' of the dataframe to 'Weather Condition'

# %%
d.rename(columns={'Weather':"Weather_Condition"},inplace=True)

# %%
d.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.3              -3.5         18                9
# 1  1/1/2012 1:00     7.4               2.8         20               24
#
#    Visibility_km  Press_kPa Weather_Condition
# 0           25.0      98.67             Clear
# 1           24.1      99.37              Rain

# %% [markdown]
# # 6) What is the mean 'Visibility' ?

# %%
d["Visibility_km"].mean()
# Out:
# 27.664446721311478

# %% [markdown]
# # 7) What is the Standard Deviation of 'Pressure' in this data?

# %%
d["Press_kPa"].std()
# Out:
# 0.8440047459486459

# %% [markdown]
# # 8) What is the Variance of 'Relative Humidity' in this data ?

# %%
d["Rel Hum_%"].var()
# Out:
# 286.2485501985015

# %% [markdown]
# # 9) Find all instances when 'Snow' was recorded.

# %%
d.loc[(d['Weather_Condition']=="Snow")]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 11     1/1/2012 11:00    -6.2              -9.6         37               35
# 70     3/1/2012 22:00    -4.0              -6.6         62               22
# 73      4/1/2012 1:00     2.3              -3.4         64               35
# 105     5/1/2012 9:00    -1.8              -4.2         73               15
# 112    5/1/2012 16:00     1.7              -0.3         75                6
# ...               ...     ...               ...        ...              ...
# 8573  9/22/2012 13:00    -6.0             -10.2         82               19
# 8650  9/25/2012 18:00    -4.6              -6.6         52                4
# 8671  9/26/2012 15:00    -5.9             -10.5         60               13
# 8713   9/28/2012 1:00    -5.2              -7.8         72               33
# 8734   9/28/2012 8:00     0.7              -1.2         79               30
#
#       Visibility_km  Press_kPa Weather_Condition
# ...

# %% [markdown]
# # 10) Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'.

# %%
 d.loc[(d["Wind Speed_km/h"]==24) & (d["Visibility_km"]==25)]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41     2/1/2012 17:00    16.2              10.9         54               24
# 166    7/1/2012 22:00     4.2               1.0         90               24
# 235   10/1/2012 19:00    -2.6              -8.5         59               24
# 652     4/3/2012 4:00    11.6               8.0         69               24
# 1001   6/4/2012 17:00   -12.6             -20.1         64               24
# ...               ...     ...               ...        ...              ...
# 8348   8/31/2012 6:00     0.2              -2.6         70               24
# 8562   9/21/2012 4:00     6.7               4.8         80               24
# 8596  9/23/2012 12:00    15.6               8.9         89               24
# 8665   9/26/2012 1:00    -0.8              -5.2         59               24
# 8712   9/28/2012 0:00    -9.0             -15.5         71               24
#
#       Visibility_km  Press_kPa Weather_Condition
# ...

# %% [markdown]
# # 11) What is the Mean value of each column against each 'Weather Condition

# %%
nam = d.groupby('Weather_Condition')

# %%
nam.mean(numeric_only=True)
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather_Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %% [markdown]
# # 12) What is the Minimum & Maximum value of each column against each 'Weather Condition ?

# %%
nam.max()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather_Condition
# Clear                                       9/9/2012 4:00    32.8
# Cloudy                                      9/9/2012 6:00    30.5
# Drizzle                                   9/15/2012 22:00    18.8
# Drizzle,Fog                                9/6/2012 10:00    19.9
# Drizzle,Ice Pellets,Fog                    7/24/2012 5:00     0.4
# Drizzle,Snow                                5/2/2012 9:00     1.2
# Drizzle,Snow,Fog                          9/21/2012 12:00     1.1
# Fog                                         9/8/2012 5:00    20.8
# Freezing Drizzle                           8/21/2012 5:00    -2.3
# Freezing Drizzle,Fog                       7/26/2012 6:00    -0.3
# Freezing Drizzle,Haze                      5/21/2012 4:00    -5.0
# Freezing Drizzle,Snow                      8/18/2012 4:00    -3.3
# Freezing Fog                               5/14/2012 9:00    -0.1
# ...

# %%
nam.min()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather_Condition
# Clear                                       1/1/2012 0:00   -23.3
# Cloudy                                     1/1/2012 10:00   -21.4
# Drizzle                                   1/18/2012 16:00     1.1
# Drizzle,Fog                               1/28/2012 12:00     0.0
# Drizzle,Ice Pellets,Fog                    7/24/2012 5:00     0.4
# Drizzle,Snow                               3/17/2012 1:00     0.9
# Drizzle,Snow,Fog                           1/25/2012 1:00     0.3
# Fog                                        1/1/2012 13:00   -16.0
# Freezing Drizzle                           2/29/2012 3:00    -9.0
# Freezing Drizzle,Fog                      10/15/2012 4:00    -6.4
# Freezing Drizzle,Haze                       1/6/2012 0:00    -5.8
# Freezing Drizzle,Snow                     1/19/2012 15:00    -8.3
# Freezing Fog                              12/31/2012 2:00   -19.0
# ...

# %% [markdown]
# # 13) Show all the Records where Weather Condition is Fog.

# %%
d.loc[d['Weather_Condition']=="Fog"]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 13     1/1/2012 13:00     9.5               7.8         40               13
# 53      3/1/2012 5:00    -3.6              -4.3         57                7
# 136    6/1/2012 16:00    14.8              13.5         80               19
# 197     9/1/2012 5:00     2.1               0.7         43               11
# 278   12/1/2012 14:00     1.2               0.6         70               13
# ...               ...     ...               ...        ...              ...
# 8475  9/18/2012 11:00     6.2               5.4         56                7
# 8511  9/19/2012 22:00    15.7              15.4         66                7
# 8518   9/19/2012 8:00    -2.9              -4.5         68                6
# 8537   9/20/2012 3:00    -0.5              -2.1         74                7
# 8771  9/30/2012 19:00    12.8              12.2         91               19
#
#       Visibility_km  Press_kPa Weather_Condition
# ...

# %% [markdown]
# # 14) Find all instances when 'Weather is Clear' or 'Visibility is above 40'.

# %%
d.loc[(d["Weather_Condition"]=="Clear") | (d["Visibility_km"]==40)]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0       1/1/2012 0:00    -1.3              -3.5         18                9
# 9       1/1/2012 9:00    20.0               3.8         35               17
# 16     1/1/2012 16:00    23.8              17.6         42                9
# 19     1/1/2012 19:00   -12.7             -17.2         43               17
# 22     1/1/2012 22:00    14.1               8.3         45                9
# ...               ...     ...               ...        ...              ...
# 8735   9/28/2012 9:00    14.2              12.9         80                4
# 8743  9/29/2012 15:00    17.7               7.8         81                9
# 8768  9/30/2012 16:00    18.2               8.8         90                4
# 8770  9/30/2012 18:00    24.6              12.6         90               15
# 8781   9/30/2012 7:00     1.5              -6.3         99               30
#
#       Visibility_km  Press_kPa Weather_Condition
# ...

# %% [markdown]
# # 15) Find all instances when 'Weather is Clear' and 'Relative Humidity is greater than 50'

# %%
d.loc[(d["Weather_Condition"]=="Clear") & (d["Rel Hum_%"]>50)]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 35     2/1/2012 11:00     9.1               6.2         53                6
# 37     2/1/2012 13:00   -12.0             -18.2         54               22
# 40     2/1/2012 16:00    21.5              10.9         54                0
# 50      3/1/2012 2:00    18.9              16.2         56                9
# 51      3/1/2012 3:00    22.2               5.5         57               19
# ...               ...     ...               ...        ...              ...
# 8735   9/28/2012 9:00    14.2              12.9         80                4
# 8743  9/29/2012 15:00    17.7               7.8         81                9
# 8768  9/30/2012 16:00    18.2               8.8         90                4
# 8770  9/30/2012 18:00    24.6              12.6         90               15
# 8781   9/30/2012 7:00     1.5              -6.3         99               30
#
#       Visibility_km  Press_kPa Weather_Condition
# ...

# %% [markdown]
# # Find all instances when 'Weather is Clear' and 'Relative Humidity is greater than 50' or . 'Weather is Clear'

# %%
d.loc[(d["Weather_Condition"]=="Clear") & (d["Rel Hum_%"]>50) | (d["Visibility_km"]>40)]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 9       1/1/2012 9:00    20.0               3.8         35               17
# 17     1/1/2012 17:00    -6.8              -9.8         42               20
# 18     1/1/2012 18:00     2.3              -2.4         42                6
# 19     1/1/2012 19:00   -12.7             -17.2         43               17
# 23     1/1/2012 23:00    29.5              16.8         45                4
# ...               ...     ...               ...        ...              ...
# 8774  9/30/2012 21:00    23.0              14.7         92               13
# 8777   9/30/2012 3:00     9.3               5.8         95                9
# 8779   9/30/2012 5:00     1.4              -3.7         97               22
# 8780   9/30/2012 6:00    -4.6              -9.5         98               11
# 8781   9/30/2012 7:00     1.5              -6.3         99               30
#
#       Visibility_km  Press_kPa Weather_Condition
# ...
